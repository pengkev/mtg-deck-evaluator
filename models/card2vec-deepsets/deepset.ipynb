# %% [markdown]
# # Classifying MTG decks with Deep Sets

# %% [markdown]
# This notebook walks through the process of building the embeddings for cards in Magic the Gathering, and then attempting to use the embeddings in a permuation-invariant classifier.

# %% [markdown]
# ### 1: Building Embeddings

# %% [markdown]
# Gensim is an open-source Python library designed specifically for unsupervised NLP learning, with highly efficient C routines. Gensim even has a built-in module for our specific use case word2vec.

# %% [markdown]
# We use an 80-10-10 split. The "Transfer Learning" component of this project is the pre-trained Word2Vec embeddings generated from a large corpus of unlabeled decks.

# %%
import json
import logging

from pathlib import Path
from gensim.models import Word2Vec

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import re

# %%
#paths for data
INPUT_FILE = Path("../../data/general-decks.jsonl")
MODEL_OUTPUT = Path("../../data/general-item2vec_mtg.model")

INPUT_EDH = Path("../../data/edh-decks.jsonl")

# %%
#Filter out "stop words"
BASIC_LANDS = {
    "Plains", "Island", "Swamp", "Mountain", "Forest", "Wastes",
    "Snow-Covered Plains", "Snow-Covered Island", "Snow-Covered Swamp", 
    "Snow-Covered Mountain", "Snow-Covered Forest"
}

# %%
#Basic logging to watch Gensim train
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.INFO)

# %% [markdown]
# Define a class to hold an MTG deck and stream from a JSONL file (potentially very large) deck by deck to protect RAM. JSONL schema looks like:
# ```
# {
#   "source": "string",          // The format, bracket, or origin of the deck (e.g., "LE", "moxfield-edh-bracket-1")
#   "deck_id": "string",         // A unique identifier for the deck
#   "mainboard": {               // A dictionary of cards in the main deck
#     "[card_name: string]": "integer" // Key is the exact card name, value is the quantity
#   },
#   "sideboard": {               // A dictionary of cards in the sideboard (optional/can be empty)
#     "[card_name: string]": "integer"
#   }
# }
# ```

# %%
class MTGDeckCorpus:
    """
    An iterable that streams decks from the JSONL file one by one.
    """
    def __init__(self, filepath, max_per_format=None):
        self.filepath = filepath
        self.max_per_format = max_per_format or {"MO": 40000, "LE": 40000}  # adjust as needed

    def __iter__(self):
        format_counts = {}
        with open(self.filepath, 'r', encoding='utf-8') as infile:
            for line in infile:
                if not line.strip():
                    continue
                
                data = json.loads(line)
                fmt = data.get("source", "CEDH")
                
                # Skip if this format is at its cap
                format_counts[fmt] = format_counts.get(fmt, 0) + 1
                if fmt in self.max_per_format and format_counts[fmt] > self.max_per_format[fmt]:
                    continue
                
                # 1. Extract cards (using .keys() automatically ignores the counts!)
                mainboard_cards = list(data.get("mainboard", {}).keys())
                sideboard_cards = list(data.get("sideboard", {}).keys())
                
                # 2. Combine and Filter
                all_cards = mainboard_cards + sideboard_cards
                clean_deck = [card for card in all_cards if card not in BASIC_LANDS]
                
                # 3. Yield the deck if it's valid
                if len(clean_deck) >= 10:
                    yield clean_deck

# %% [markdown]
# To train embeddings model, simply import use Word2Vec as imported from Gensim and train

# %%
EMBEDDING_SIZE = 512

def train_embeddings():
    print(f"Initializing stream from {INPUT_FILE}...")
    sentences = MTGDeckCorpus(INPUT_FILE)
    
    # Ensure output directory exists
    MODEL_OUTPUT.parent.mkdir(parents=True, exist_ok=True)
    
    print("Training Gensim Word2Vec Model...")
    # --- GENSIM MAGIC HAPPENS HERE ---
    model = Word2Vec(
        sentences=sentences, 
        vector_size=EMBEDDING_SIZE,  # The size of the latent space / hidden layer
        window=115,       # The "Infinite Window": big enough to cover a whole deck
        min_count=5,      # Ignore cards that appear in fewer than 5 decks total
        sg=1,             # 1 = Skip-Gram (Item2Vec), 0 = CBOW
        workers=8,        # Number of CPU cores to use (Adjust based on your rig)
        epochs=10         # Pass over the dataset 10 times
    )
    
    print(f"Training complete! Saving model to {MODEL_OUTPUT}")
    model.save(str(MODEL_OUTPUT))

# %%
train_embeddings()
# Out:
# 2026-03-13 18:07:59,044 : INFO : collecting all words and their counts
# 2026-03-13 18:07:59,045 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2026-03-13 18:07:59,184 : INFO : PROGRESS: at sentence #10000, processed 297369 words, keeping 1885 word types
# Initializing stream from ..\..\data\general-decks.jsonl...
# Training Gensim Word2Vec Model...
# 2026-03-13 18:07:59,327 : INFO : PROGRESS: at sentence #20000, processed 605163 words, keeping 2884 word types
# 2026-03-13 18:07:59,483 : INFO : PROGRESS: at sentence #30000, processed 911628 words, keeping 3621 word types
# 2026-03-13 18:07:59,904 : INFO : PROGRESS: at sentence #40000, processed 1214893 words, keeping 4076 word types
# 2026-03-13 18:08:00,040 : INFO : PROGRESS: at sentence #50000, processed 1500115 words, keeping 4879 word types
# 2026-03-13 18:08:00,191 : INFO : PROGRESS: at sentence #60000, processed 1789938 words, keeping 5379 word types
# 2026-03-13 18:08:00,337 : INFO : PROGRESS: at sentence #70000, processed 2083806 words, keeping 5752 word types
# 2026-03-13 18:08:01,001 : INFO : PROGRESS: at sentence #80000, processed 2388436 words, keeping 5961 word types
# 2026-03-13 18:08:01,147 : INFO : PROGRESS: at sentence #90000, processed 2715842 words, keeping 6764 word types
# 2026-03-13 18:08:01,316 : INFO : PROGRESS: at sentence #100000, processed 3116534 words, keeping 6960 word types
# 2026-03-13 18:08:01,638 : INFO : PROGRESS: at sentence #110000, processed 3926389 words, keeping 12549 word types
# 2026-03-13 18:08:02,017 : INFO : PROGRESS: at sentence #120000, processed 4891853 words, keeping 15588 word types
# 2026-03-13 18:08:02,348 : INFO : collected 17078 word types from a corpus of 5762447 raw words and 129004 sentences
# 2026-03-13 18:08:02,349 : INFO : Creating a fresh vocabulary
# 2026-03-13 18:08:02,364 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 10037 unique words (58.77% of original 17078, drops 7041)', 'datetime': '2026-03-13T18:08:02.364514', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'prepare_vocab'}
# 2026-03-13 18:08:02,365 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 5748418 word corpus (99.76% of original 5762447, drops 14029)', 'datetime': '2026-03-13T18:08:02.364988', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'prepare_vocab'}
# 2026-03-13 18:08:02,390 : INFO : deleting the raw counts dictionary of 17078 items
# 2026-03-13 18:08:02,391 : INFO : sample=0.001 downsamples 76 most-common words
# 2026-03-13 18:08:02,391 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 5194768.504568374 word corpus (90.4%% of prior 5748418)', 'datetime': '2026-03-13T18:08:02.391566', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'prepare_vocab'}
# 2026-03-13 18:08:02,435 : INFO : estimated required memory for 10037 words and 512 dimensions: 46130052 bytes
# 2026-03-13 18:08:02,436 : INFO : resetting layer weights
# 2026-03-13 18:08:02,450 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2026-03-13T18:08:02.450421', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'build_vocab'}
# 2026-03-13 18:08:02,451 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 10037 vocabulary and 512 features, using sg=1 hs=0 sample=0.001 negative=5 window=115 shrink_windows=True', 'datetime': '2026-03-13T18:08:02.451187', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'train'}
# 2026-03-13 18:08:03,665 : INFO : EPOCH 0 - PROGRESS: at 6.52% examples, 180177 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:04,671 : INFO : EPOCH 0 - PROGRESS: at 12.82% examples, 197278 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:05,672 : INFO : EPOCH 0 - PROGRESS: at 19.35% examples, 206566 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:06,862 : INFO : EPOCH 0 - PROGRESS: at 26.75% examples, 208057 words/s, in_qsize 8, out_qsize 0
# 2026-03-13 18:08:07,973 : INFO : EPOCH 0 - PROGRESS: at 33.30% examples, 206885 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:09,069 : INFO : EPOCH 0 - PROGRESS: at 39.53% examples, 205787 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:10,100 : INFO : EPOCH 0 - PROGRESS: at 45.93% examples, 207855 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:11,114 : INFO : EPOCH 0 - PROGRESS: at 52.28% examples, 209664 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:12,266 : INFO : EPOCH 0 - PROGRESS: at 58.36% examples, 207826 words/s, in_qsize 6, out_qsize 0
# 2026-03-13 18:08:13,331 : INFO : EPOCH 0 - PROGRESS: at 65.55% examples, 209153 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:14,412 : INFO : EPOCH 0 - PROGRESS: at 69.77% examples, 206315 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:15,461 : INFO : EPOCH 0 - PROGRESS: at 73.42% examples, 202344 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:16,613 : INFO : EPOCH 0 - PROGRESS: at 77.88% examples, 200016 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:17,709 : INFO : EPOCH 0 - PROGRESS: at 79.65% examples, 191397 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:18,763 : INFO : EPOCH 0 - PROGRESS: at 80.65% examples, 185659 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:19,967 : INFO : EPOCH 0 - PROGRESS: at 81.47% examples, 178028 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:21,036 : INFO : EPOCH 0 - PROGRESS: at 82.20% examples, 172130 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:22,410 : INFO : EPOCH 0 - PROGRESS: at 82.92% examples, 164301 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:23,410 : INFO : EPOCH 0 - PROGRESS: at 83.88% examples, 161576 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:24,568 : INFO : EPOCH 0 - PROGRESS: at 84.67% examples, 157151 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:26,053 : INFO : EPOCH 0 - PROGRESS: at 85.47% examples, 151053 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:27,091 : INFO : EPOCH 0 - PROGRESS: at 86.43% examples, 149036 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:28,273 : INFO : EPOCH 0 - PROGRESS: at 87.23% examples, 145672 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:29,306 : INFO : EPOCH 0 - PROGRESS: at 87.95% examples, 143064 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:30,778 : INFO : EPOCH 0 - PROGRESS: at 88.67% examples, 138466 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:31,820 : INFO : EPOCH 0 - PROGRESS: at 89.47% examples, 136603 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:32,865 : INFO : EPOCH 0 - PROGRESS: at 90.19% examples, 134560 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:33,897 : INFO : EPOCH 0 - PROGRESS: at 90.91% examples, 132718 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:34,943 : INFO : EPOCH 0 - PROGRESS: at 91.63% examples, 130924 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:36,096 : INFO : EPOCH 0 - PROGRESS: at 92.35% examples, 128836 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:37,604 : INFO : EPOCH 0 - PROGRESS: at 93.15% examples, 125853 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:38,678 : INFO : EPOCH 0 - PROGRESS: at 94.03% examples, 124845 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:39,682 : INFO : EPOCH 0 - PROGRESS: at 94.75% examples, 123651 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:40,732 : INFO : EPOCH 0 - PROGRESS: at 95.47% examples, 122368 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:41,906 : INFO : EPOCH 0 - PROGRESS: at 96.19% examples, 120770 words/s, in_qsize 14, out_qsize 1
# 2026-03-13 18:08:43,272 : INFO : EPOCH 0 - PROGRESS: at 96.98% examples, 118924 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:44,370 : INFO : EPOCH 0 - PROGRESS: at 97.77% examples, 117949 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:45,399 : INFO : EPOCH 0 - PROGRESS: at 98.57% examples, 117211 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:46,461 : INFO : EPOCH 0 - PROGRESS: at 99.29% examples, 116221 words/s, in_qsize 9, out_qsize 0
# 2026-03-13 18:08:47,378 : INFO : EPOCH 0: training on 5762447 raw words (5194130 effective words) took 44.9s, 115630 effective words/s
# 2026-03-13 18:08:48,405 : INFO : EPOCH 1 - PROGRESS: at 6.26% examples, 204635 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:49,530 : INFO : EPOCH 1 - PROGRESS: at 12.33% examples, 195568 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:50,650 : INFO : EPOCH 1 - PROGRESS: at 18.36% examples, 192829 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:51,656 : INFO : EPOCH 1 - PROGRESS: at 24.71% examples, 198377 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:52,672 : INFO : EPOCH 1 - PROGRESS: at 30.83% examples, 199750 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:53,750 : INFO : EPOCH 1 - PROGRESS: at 37.87% examples, 204766 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:54,774 : INFO : EPOCH 1 - PROGRESS: at 44.36% examples, 207294 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:55,821 : INFO : EPOCH 1 - PROGRESS: at 50.70% examples, 208497 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:56,854 : INFO : EPOCH 1 - PROGRESS: at 56.60% examples, 208410 words/s, in_qsize 13, out_qsize 0
# 2026-03-13 18:08:57,859 : INFO : EPOCH 1 - PROGRESS: at 62.63% examples, 208839 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:08:58,878 : INFO : EPOCH 1 - PROGRESS: at 67.88% examples, 207064 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:08:59,889 : INFO : EPOCH 1 - PROGRESS: at 71.12% examples, 202106 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:00,989 : INFO : EPOCH 1 - PROGRESS: at 74.79% examples, 197885 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:02,034 : INFO : EPOCH 1 - PROGRESS: at 78.83% examples, 196257 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:03,047 : INFO : EPOCH 1 - PROGRESS: at 79.99% examples, 188691 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:04,048 : INFO : EPOCH 1 - PROGRESS: at 80.57% examples, 181135 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:05,375 : INFO : EPOCH 1 - PROGRESS: at 81.39% examples, 172776 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:06,518 : INFO : EPOCH 1 - PROGRESS: at 82.12% examples, 166682 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:07,801 : INFO : EPOCH 1 - PROGRESS: at 82.84% examples, 160142 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:08,833 : INFO : EPOCH 1 - PROGRESS: at 83.48% examples, 155764 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:09,889 : INFO : EPOCH 1 - PROGRESS: at 84.20% examples, 152028 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:10,911 : INFO : EPOCH 1 - PROGRESS: at 84.91% examples, 148835 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:12,208 : INFO : EPOCH 1 - PROGRESS: at 85.79% examples, 145034 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:13,378 : INFO : EPOCH 1 - PROGRESS: at 86.43% examples, 141249 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:14,412 : INFO : EPOCH 1 - PROGRESS: at 87.07% examples, 138494 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:15,454 : INFO : EPOCH 1 - PROGRESS: at 87.79% examples, 136220 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:16,714 : INFO : EPOCH 1 - PROGRESS: at 88.51% examples, 133112 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:17,840 : INFO : EPOCH 1 - PROGRESS: at 89.15% examples, 130543 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:18,842 : INFO : EPOCH 1 - PROGRESS: at 89.87% examples, 128948 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:19,885 : INFO : EPOCH 1 - PROGRESS: at 90.67% examples, 127566 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:20,898 : INFO : EPOCH 1 - PROGRESS: at 91.39% examples, 126114 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:22,242 : INFO : EPOCH 1 - PROGRESS: at 92.10% examples, 123566 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:23,286 : INFO : EPOCH 1 - PROGRESS: at 92.75% examples, 121964 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:24,406 : INFO : EPOCH 1 - PROGRESS: at 93.55% examples, 120703 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:25,506 : INFO : EPOCH 1 - PROGRESS: at 94.19% examples, 119107 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:26,544 : INFO : EPOCH 1 - PROGRESS: at 94.83% examples, 117787 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:27,545 : INFO : EPOCH 1 - PROGRESS: at 95.63% examples, 117085 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:28,610 : INFO : EPOCH 1 - PROGRESS: at 96.34% examples, 116014 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:29,613 : INFO : EPOCH 1 - PROGRESS: at 97.06% examples, 115171 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:30,747 : INFO : EPOCH 1 - PROGRESS: at 97.77% examples, 114021 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:31,785 : INFO : EPOCH 1 - PROGRESS: at 98.41% examples, 112972 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:32,827 : INFO : EPOCH 1 - PROGRESS: at 99.05% examples, 111961 words/s, in_qsize 12, out_qsize 0
# 2026-03-13 18:09:33,913 : INFO : EPOCH 1 - PROGRESS: at 99.92% examples, 111454 words/s, in_qsize 1, out_qsize 1
# 2026-03-13 18:09:33,922 : INFO : EPOCH 1: training on 5762447 raw words (5194986 effective words) took 46.5s, 111626 effective words/s
# 2026-03-13 18:09:35,169 : INFO : EPOCH 2 - PROGRESS: at 6.52% examples, 175151 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:36,170 : INFO : EPOCH 2 - PROGRESS: at 13.08% examples, 198627 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:37,207 : INFO : EPOCH 2 - PROGRESS: at 19.10% examples, 199813 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:38,224 : INFO : EPOCH 2 - PROGRESS: at 25.22% examples, 201214 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:09:39,241 : INFO : EPOCH 2 - PROGRESS: at 31.10% examples, 200409 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:40,248 : INFO : EPOCH 2 - PROGRESS: at 37.87% examples, 206200 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:41,263 : INFO : EPOCH 2 - PROGRESS: at 44.36% examples, 208802 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:42,298 : INFO : EPOCH 2 - PROGRESS: at 50.43% examples, 209025 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:43,364 : INFO : EPOCH 2 - PROGRESS: at 56.60% examples, 209138 words/s, in_qsize 13, out_qsize 0
# 2026-03-13 18:09:44,381 : INFO : EPOCH 2 - PROGRESS: at 64.70% examples, 214868 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:09:45,414 : INFO : EPOCH 2 - PROGRESS: at 68.45% examples, 209440 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:46,623 : INFO : EPOCH 2 - PROGRESS: at 71.70% examples, 201081 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:47,872 : INFO : EPOCH 2 - PROGRESS: at 76.34% examples, 198038 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:48,957 : INFO : EPOCH 2 - PROGRESS: at 79.57% examples, 193620 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:49,962 : INFO : EPOCH 2 - PROGRESS: at 80.24% examples, 185982 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:50,976 : INFO : EPOCH 2 - PROGRESS: at 80.89% examples, 179152 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:51,993 : INFO : EPOCH 2 - PROGRESS: at 81.55% examples, 173043 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:53,008 : INFO : EPOCH 2 - PROGRESS: at 82.20% examples, 167595 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:54,421 : INFO : EPOCH 2 - PROGRESS: at 82.92% examples, 159959 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:55,437 : INFO : EPOCH 2 - PROGRESS: at 83.56% examples, 155727 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:56,470 : INFO : EPOCH 2 - PROGRESS: at 84.44% examples, 152948 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:57,682 : INFO : EPOCH 2 - PROGRESS: at 85.31% examples, 149282 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:09:58,888 : INFO : EPOCH 2 - PROGRESS: at 86.03% examples, 145299 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:00,351 : INFO : EPOCH 2 - PROGRESS: at 86.75% examples, 140292 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:01,357 : INFO : EPOCH 2 - PROGRESS: at 87.55% examples, 138410 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:02,358 : INFO : EPOCH 2 - PROGRESS: at 88.35% examples, 136684 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:03,562 : INFO : EPOCH 2 - PROGRESS: at 89.15% examples, 134149 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:04,768 : INFO : EPOCH 2 - PROGRESS: at 89.87% examples, 131517 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:06,245 : INFO : EPOCH 2 - PROGRESS: at 90.59% examples, 127999 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:07,267 : INFO : EPOCH 2 - PROGRESS: at 91.55% examples, 127298 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:08,287 : INFO : EPOCH 2 - PROGRESS: at 92.27% examples, 125868 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:09,446 : INFO : EPOCH 2 - PROGRESS: at 92.99% examples, 124027 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:10,732 : INFO : EPOCH 2 - PROGRESS: at 93.71% examples, 121895 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:11,979 : INFO : EPOCH 2 - PROGRESS: at 94.43% examples, 120027 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:13,092 : INFO : EPOCH 2 - PROGRESS: at 95.15% examples, 118679 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:14,099 : INFO : EPOCH 2 - PROGRESS: at 95.87% examples, 117711 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:15,101 : INFO : EPOCH 2 - PROGRESS: at 96.66% examples, 117021 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:16,180 : INFO : EPOCH 2 - PROGRESS: at 97.38% examples, 115941 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:17,395 : INFO : EPOCH 2 - PROGRESS: at 98.09% examples, 114562 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:18,595 : INFO : EPOCH 2 - PROGRESS: at 98.81% examples, 113290 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:19,792 : INFO : EPOCH 2 - PROGRESS: at 99.53% examples, 112092 words/s, in_qsize 6, out_qsize 1
# 2026-03-13 18:10:20,051 : INFO : EPOCH 2: training on 5762447 raw words (5194297 effective words) took 46.1s, 112615 effective words/s
# 2026-03-13 18:10:21,274 : INFO : EPOCH 3 - PROGRESS: at 6.52% examples, 178551 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:22,301 : INFO : EPOCH 3 - PROGRESS: at 12.83% examples, 194575 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:23,321 : INFO : EPOCH 3 - PROGRESS: at 18.61% examples, 195441 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:24,328 : INFO : EPOCH 3 - PROGRESS: at 24.71% examples, 198293 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:25,378 : INFO : EPOCH 3 - PROGRESS: at 30.83% examples, 198442 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:26,386 : INFO : EPOCH 3 - PROGRESS: at 37.60% examples, 204375 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:27,399 : INFO : EPOCH 3 - PROGRESS: at 44.36% examples, 208584 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:28,401 : INFO : EPOCH 3 - PROGRESS: at 50.17% examples, 208540 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:29,449 : INFO : EPOCH 3 - PROGRESS: at 56.35% examples, 209129 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:10:30,450 : INFO : EPOCH 3 - PROGRESS: at 63.32% examples, 212349 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:31,553 : INFO : EPOCH 3 - PROGRESS: at 68.26% examples, 208512 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:32,691 : INFO : EPOCH 3 - PROGRESS: at 71.70% examples, 202081 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:33,724 : INFO : EPOCH 3 - PROGRESS: at 75.95% examples, 200785 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:34,900 : INFO : EPOCH 3 - PROGRESS: at 79.41% examples, 195465 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:35,903 : INFO : EPOCH 3 - PROGRESS: at 80.15% examples, 187633 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:36,919 : INFO : EPOCH 3 - PROGRESS: at 80.81% examples, 180610 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:38,013 : INFO : EPOCH 3 - PROGRESS: at 81.47% examples, 173610 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:39,036 : INFO : EPOCH 3 - PROGRESS: at 82.12% examples, 168036 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:40,042 : INFO : EPOCH 3 - PROGRESS: at 82.76% examples, 163153 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:41,151 : INFO : EPOCH 3 - PROGRESS: at 83.48% examples, 158385 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:42,599 : INFO : EPOCH 3 - PROGRESS: at 84.20% examples, 151776 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:43,609 : INFO : EPOCH 3 - PROGRESS: at 84.91% examples, 148686 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:44,617 : INFO : EPOCH 3 - PROGRESS: at 85.64% examples, 145862 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:45,656 : INFO : EPOCH 3 - PROGRESS: at 86.43% examples, 143431 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:46,677 : INFO : EPOCH 3 - PROGRESS: at 87.15% examples, 140958 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:47,718 : INFO : EPOCH 3 - PROGRESS: at 87.79% examples, 138235 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:49,064 : INFO : EPOCH 3 - PROGRESS: at 88.51% examples, 134601 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:50,471 : INFO : EPOCH 3 - PROGRESS: at 89.31% examples, 131324 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:51,471 : INFO : EPOCH 3 - PROGRESS: at 90.03% examples, 129712 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:52,494 : INFO : EPOCH 3 - PROGRESS: at 90.75% examples, 128103 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:53,507 : INFO : EPOCH 3 - PROGRESS: at 91.47% examples, 126632 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:54,526 : INFO : EPOCH 3 - PROGRESS: at 92.19% examples, 125224 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:55,596 : INFO : EPOCH 3 - PROGRESS: at 92.90% examples, 123713 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:56,903 : INFO : EPOCH 3 - PROGRESS: at 93.63% examples, 121524 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:10:57,980 : INFO : EPOCH 3 - PROGRESS: at 94.35% examples, 120208 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:10:59,269 : INFO : EPOCH 3 - PROGRESS: at 95.07% examples, 118322 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:00,281 : INFO : EPOCH 3 - PROGRESS: at 95.79% examples, 117350 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:01,302 : INFO : EPOCH 3 - PROGRESS: at 96.50% examples, 116399 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:02,356 : INFO : EPOCH 3 - PROGRESS: at 97.22% examples, 115406 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:03,796 : INFO : EPOCH 3 - PROGRESS: at 98.09% examples, 113862 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:05,084 : INFO : EPOCH 3 - PROGRESS: at 98.89% examples, 112598 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:11:06,089 : INFO : EPOCH 3 - PROGRESS: at 99.61% examples, 111892 words/s, in_qsize 5, out_qsize 1
# 2026-03-13 18:11:06,424 : INFO : EPOCH 3: training on 5762447 raw words (5195047 effective words) took 46.4s, 112038 effective words/s
# 2026-03-13 18:11:07,534 : INFO : EPOCH 4 - PROGRESS: at 6.26% examples, 188878 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:08,641 : INFO : EPOCH 4 - PROGRESS: at 12.33% examples, 189586 words/s, in_qsize 15, out_qsize 1
# 2026-03-13 18:11:09,643 : INFO : EPOCH 4 - PROGRESS: at 18.36% examples, 195808 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:10,664 : INFO : EPOCH 4 - PROGRESS: at 24.20% examples, 195922 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:11,708 : INFO : EPOCH 4 - PROGRESS: at 30.30% examples, 196735 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:12,716 : INFO : EPOCH 4 - PROGRESS: at 37.33% examples, 204260 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:13,776 : INFO : EPOCH 4 - PROGRESS: at 44.10% examples, 207186 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:14,850 : INFO : EPOCH 4 - PROGRESS: at 50.44% examples, 207773 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:15,857 : INFO : EPOCH 4 - PROGRESS: at 56.10% examples, 207370 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:16,860 : INFO : EPOCH 4 - PROGRESS: at 61.96% examples, 207861 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:17,866 : INFO : EPOCH 4 - PROGRESS: at 67.13% examples, 205061 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:18,902 : INFO : EPOCH 4 - PROGRESS: at 70.92% examples, 201904 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:20,078 : INFO : EPOCH 4 - PROGRESS: at 74.58% examples, 196603 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:21,081 : INFO : EPOCH 4 - PROGRESS: at 78.45% examples, 195032 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:22,157 : INFO : EPOCH 4 - PROGRESS: at 79.74% examples, 186176 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:23,160 : INFO : EPOCH 4 - PROGRESS: at 80.40% examples, 179331 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:24,173 : INFO : EPOCH 4 - PROGRESS: at 81.06% examples, 173156 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:25,193 : INFO : EPOCH 4 - PROGRESS: at 81.72% examples, 167578 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:26,214 : INFO : EPOCH 4 - PROGRESS: at 82.44% examples, 162992 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:27,270 : INFO : EPOCH 4 - PROGRESS: at 83.16% examples, 158577 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:28,280 : INFO : EPOCH 4 - PROGRESS: at 83.80% examples, 154523 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:29,367 : INFO : EPOCH 4 - PROGRESS: at 84.44% examples, 150306 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:30,383 : INFO : EPOCH 4 - PROGRESS: at 85.07% examples, 146905 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:31,490 : INFO : EPOCH 4 - PROGRESS: at 85.79% examples, 143636 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:32,681 : INFO : EPOCH 4 - PROGRESS: at 86.51% examples, 140174 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:34,064 : INFO : EPOCH 4 - PROGRESS: at 87.23% examples, 136074 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:35,081 : INFO : EPOCH 4 - PROGRESS: at 87.95% examples, 134052 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:36,093 : INFO : EPOCH 4 - PROGRESS: at 88.67% examples, 132200 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:37,197 : INFO : EPOCH 4 - PROGRESS: at 89.39% examples, 130067 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:38,324 : INFO : EPOCH 4 - PROGRESS: at 90.11% examples, 127998 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:39,443 : INFO : EPOCH 4 - PROGRESS: at 90.83% examples, 126106 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:40,660 : INFO : EPOCH 4 - PROGRESS: at 91.55% examples, 123973 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:41,971 : INFO : EPOCH 4 - PROGRESS: at 92.27% examples, 121667 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:43,072 : INFO : EPOCH 4 - PROGRESS: at 93.07% examples, 120454 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:44,106 : INFO : EPOCH 4 - PROGRESS: at 93.79% examples, 119295 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:45,249 : INFO : EPOCH 4 - PROGRESS: at 94.51% examples, 117872 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:46,443 : INFO : EPOCH 4 - PROGRESS: at 95.23% examples, 116376 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:47,599 : INFO : EPOCH 4 - PROGRESS: at 95.95% examples, 115070 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:48,830 : INFO : EPOCH 4 - PROGRESS: at 96.66% examples, 113632 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:49,959 : INFO : EPOCH 4 - PROGRESS: at 97.46% examples, 112744 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:50,967 : INFO : EPOCH 4 - PROGRESS: at 98.17% examples, 112005 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:52,147 : INFO : EPOCH 4 - PROGRESS: at 98.89% examples, 110880 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:11:53,311 : INFO : EPOCH 4 - PROGRESS: at 99.61% examples, 109848 words/s, in_qsize 5, out_qsize 1
# 2026-03-13 18:11:53,630 : INFO : EPOCH 4: training on 5762447 raw words (5194136 effective words) took 47.2s, 110043 effective words/s
# 2026-03-13 18:11:54,882 : INFO : EPOCH 5 - PROGRESS: at 6.52% examples, 174618 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:55,885 : INFO : EPOCH 5 - PROGRESS: at 12.57% examples, 190231 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:56,912 : INFO : EPOCH 5 - PROGRESS: at 18.61% examples, 194688 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:57,934 : INFO : EPOCH 5 - PROGRESS: at 24.71% examples, 196998 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:11:58,976 : INFO : EPOCH 5 - PROGRESS: at 30.83% examples, 197678 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:11:59,980 : INFO : EPOCH 5 - PROGRESS: at 37.60% examples, 203884 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:00,993 : INFO : EPOCH 5 - PROGRESS: at 44.62% examples, 209429 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:02,001 : INFO : EPOCH 5 - PROGRESS: at 50.17% examples, 207984 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:03,085 : INFO : EPOCH 5 - PROGRESS: at 56.35% examples, 207837 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:12:04,087 : INFO : EPOCH 5 - PROGRESS: at 64.01% examples, 213026 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:05,151 : INFO : EPOCH 5 - PROGRESS: at 68.26% examples, 208161 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:06,209 : INFO : EPOCH 5 - PROGRESS: at 71.51% examples, 202373 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:07,230 : INFO : EPOCH 5 - PROGRESS: at 75.18% examples, 199311 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:08,406 : INFO : EPOCH 5 - PROGRESS: at 79.21% examples, 195844 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:09,416 : INFO : EPOCH 5 - PROGRESS: at 80.07% examples, 187862 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:10,451 : INFO : EPOCH 5 - PROGRESS: at 80.73% examples, 180571 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:11,627 : INFO : EPOCH 5 - PROGRESS: at 81.47% examples, 173266 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:12,654 : INFO : EPOCH 5 - PROGRESS: at 82.12% examples, 167694 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:13,691 : INFO : EPOCH 5 - PROGRESS: at 82.76% examples, 162588 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:14,701 : INFO : EPOCH 5 - PROGRESS: at 83.40% examples, 158187 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:15,871 : INFO : EPOCH 5 - PROGRESS: at 84.11% examples, 153477 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:17,257 : INFO : EPOCH 5 - PROGRESS: at 84.83% examples, 147867 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:18,323 : INFO : EPOCH 5 - PROGRESS: at 85.56% examples, 144748 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:19,380 : INFO : EPOCH 5 - PROGRESS: at 86.19% examples, 141578 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:20,420 : INFO : EPOCH 5 - PROGRESS: at 86.99% examples, 139419 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:21,437 : INFO : EPOCH 5 - PROGRESS: at 87.63% examples, 136891 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:22,438 : INFO : EPOCH 5 - PROGRESS: at 88.27% examples, 134617 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:23,570 : INFO : EPOCH 5 - PROGRESS: at 89.07% examples, 132516 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:24,614 : INFO : EPOCH 5 - PROGRESS: at 89.71% examples, 130358 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:25,633 : INFO : EPOCH 5 - PROGRESS: at 90.34% examples, 128446 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:26,774 : INFO : EPOCH 5 - PROGRESS: at 91.07% examples, 126457 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:28,077 : INFO : EPOCH 5 - PROGRESS: at 91.79% examples, 124009 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:29,318 : INFO : EPOCH 5 - PROGRESS: at 92.51% examples, 121962 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:30,411 : INFO : EPOCH 5 - PROGRESS: at 93.23% examples, 120531 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:31,508 : INFO : EPOCH 5 - PROGRESS: at 93.94% examples, 119177 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:32,510 : INFO : EPOCH 5 - PROGRESS: at 94.59% examples, 117962 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:33,524 : INFO : EPOCH 5 - PROGRESS: at 95.31% examples, 116984 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:34,525 : INFO : EPOCH 5 - PROGRESS: at 95.95% examples, 115872 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:35,554 : INFO : EPOCH 5 - PROGRESS: at 96.66% examples, 114951 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:36,785 : INFO : EPOCH 5 - PROGRESS: at 97.46% examples, 113750 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:38,083 : INFO : EPOCH 5 - PROGRESS: at 98.17% examples, 112249 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:39,194 : INFO : EPOCH 5 - PROGRESS: at 98.89% examples, 111283 words/s, in_qsize 14, out_qsize 0
# 2026-03-13 18:12:40,204 : INFO : EPOCH 5 - PROGRESS: at 99.61% examples, 110606 words/s, in_qsize 5, out_qsize 1
# 2026-03-13 18:12:40,514 : INFO : EPOCH 5: training on 5762447 raw words (5194932 effective words) took 46.9s, 110816 effective words/s
# 2026-03-13 18:12:41,781 : INFO : EPOCH 6 - PROGRESS: at 6.52% examples, 172506 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:42,792 : INFO : EPOCH 6 - PROGRESS: at 12.57% examples, 188481 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:43,824 : INFO : EPOCH 6 - PROGRESS: at 18.61% examples, 193118 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:44,892 : INFO : EPOCH 6 - PROGRESS: at 24.97% examples, 195787 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:45,947 : INFO : EPOCH 6 - PROGRESS: at 31.10% examples, 196209 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:46,954 : INFO : EPOCH 6 - PROGRESS: at 38.69% examples, 206987 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:47,964 : INFO : EPOCH 6 - PROGRESS: at 45.14% examples, 209531 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:48,977 : INFO : EPOCH 6 - PROGRESS: at 50.70% examples, 207943 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:50,007 : INFO : EPOCH 6 - PROGRESS: at 56.60% examples, 208016 words/s, in_qsize 13, out_qsize 0
# 2026-03-13 18:12:51,036 : INFO : EPOCH 6 - PROGRESS: at 63.32% examples, 209873 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:52,044 : INFO : EPOCH 6 - PROGRESS: at 68.26% examples, 208019 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:53,074 : INFO : EPOCH 6 - PROGRESS: at 71.51% examples, 202658 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:12:54,119 : INFO : EPOCH 6 - PROGRESS: at 74.79% examples, 197954 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:55,122 : INFO : EPOCH 6 - PROGRESS: at 79.02% examples, 197507 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:56,134 : INFO : EPOCH 6 - PROGRESS: at 79.82% examples, 188134 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:57,153 : INFO : EPOCH 6 - PROGRESS: at 80.48% examples, 180928 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:58,172 : INFO : EPOCH 6 - PROGRESS: at 81.14% examples, 174568 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:12:59,215 : INFO : EPOCH 6 - PROGRESS: at 81.80% examples, 168675 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:00,247 : INFO : EPOCH 6 - PROGRESS: at 82.44% examples, 163483 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:01,285 : INFO : EPOCH 6 - PROGRESS: at 83.08% examples, 158754 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:02,300 : INFO : EPOCH 6 - PROGRESS: at 83.72% examples, 154632 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:03,301 : INFO : EPOCH 6 - PROGRESS: at 84.36% examples, 150972 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:04,310 : INFO : EPOCH 6 - PROGRESS: at 84.99% examples, 147573 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:05,311 : INFO : EPOCH 6 - PROGRESS: at 85.64% examples, 144509 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:06,328 : INFO : EPOCH 6 - PROGRESS: at 86.27% examples, 141571 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:07,338 : INFO : EPOCH 6 - PROGRESS: at 86.99% examples, 139240 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:13:08,340 : INFO : EPOCH 6 - PROGRESS: at 87.55% examples, 136477 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:09,353 : INFO : EPOCH 6 - PROGRESS: at 88.19% examples, 134150 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:13:10,401 : INFO : EPOCH 6 - PROGRESS: at 88.83% examples, 131843 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:11,422 : INFO : EPOCH 6 - PROGRESS: at 89.55% examples, 130088 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:13:12,422 : INFO : EPOCH 6 - PROGRESS: at 90.11% examples, 127983 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:13,456 : INFO : EPOCH 6 - PROGRESS: at 90.75% examples, 126136 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:14,469 : INFO : EPOCH 6 - PROGRESS: at 91.47% examples, 124746 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:15,504 : INFO : EPOCH 6 - PROGRESS: at 92.03% examples, 122848 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:16,516 : INFO : EPOCH 6 - PROGRESS: at 92.75% examples, 121632 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:17,537 : INFO : EPOCH 6 - PROGRESS: at 93.39% examples, 120218 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:18,564 : INFO : EPOCH 6 - PROGRESS: at 94.11% examples, 119101 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:19,577 : INFO : EPOCH 6 - PROGRESS: at 94.75% examples, 117858 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:20,589 : INFO : EPOCH 6 - PROGRESS: at 95.39% examples, 116674 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:21,591 : INFO : EPOCH 6 - PROGRESS: at 96.11% examples, 115790 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:22,804 : INFO : EPOCH 6 - PROGRESS: at 96.82% examples, 114378 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:24,155 : INFO : EPOCH 6 - PROGRESS: at 97.53% examples, 112687 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:25,211 : INFO : EPOCH 6 - PROGRESS: at 98.25% examples, 111826 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:26,418 : INFO : EPOCH 6 - PROGRESS: at 98.97% examples, 110644 words/s, in_qsize 13, out_qsize 0
# 2026-03-13 18:13:27,486 : INFO : EPOCH 6 - PROGRESS: at 99.85% examples, 110236 words/s, in_qsize 2, out_qsize 1
# 2026-03-13 18:13:27,587 : INFO : EPOCH 6: training on 5762447 raw words (5194631 effective words) took 47.1s, 110363 effective words/s
# 2026-03-13 18:13:28,597 : INFO : EPOCH 7 - PROGRESS: at 5.49% examples, 181433 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:29,602 : INFO : EPOCH 7 - PROGRESS: at 11.08% examples, 186908 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:30,631 : INFO : EPOCH 7 - PROGRESS: at 16.35% examples, 184100 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:31,652 : INFO : EPOCH 7 - PROGRESS: at 22.65% examples, 191491 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:32,659 : INFO : EPOCH 7 - PROGRESS: at 28.26% examples, 191176 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:13:33,664 : INFO : EPOCH 7 - PROGRESS: at 34.65% examples, 195709 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:34,793 : INFO : EPOCH 7 - PROGRESS: at 41.97% examples, 200758 words/s, in_qsize 14, out_qsize 1
# 2026-03-13 18:13:35,805 : INFO : EPOCH 7 - PROGRESS: at 48.03% examples, 202591 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:36,885 : INFO : EPOCH 7 - PROGRESS: at 54.34% examples, 203291 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:37,897 : INFO : EPOCH 7 - PROGRESS: at 60.16% examples, 204079 words/s, in_qsize 0, out_qsize 0
# 2026-03-13 18:13:38,906 : INFO : EPOCH 7 - PROGRESS: at 66.54% examples, 204908 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:39,941 : INFO : EPOCH 7 - PROGRESS: at 69.58% examples, 199019 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:40,951 : INFO : EPOCH 7 - PROGRESS: at 72.84% examples, 194991 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:41,978 : INFO : EPOCH 7 - PROGRESS: at 76.53% examples, 192557 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:43,025 : INFO : EPOCH 7 - PROGRESS: at 79.57% examples, 188562 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:44,074 : INFO : EPOCH 7 - PROGRESS: at 80.24% examples, 180942 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:45,078 : INFO : EPOCH 7 - PROGRESS: at 80.89% examples, 174671 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:46,106 : INFO : EPOCH 7 - PROGRESS: at 81.47% examples, 168383 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:47,138 : INFO : EPOCH 7 - PROGRESS: at 82.12% examples, 163166 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:48,161 : INFO : EPOCH 7 - PROGRESS: at 82.76% examples, 158525 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:49,177 : INFO : EPOCH 7 - PROGRESS: at 83.40% examples, 154371 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:13:50,203 : INFO : EPOCH 7 - PROGRESS: at 84.04% examples, 150529 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:51,269 : INFO : EPOCH 7 - PROGRESS: at 84.67% examples, 146765 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:52,689 : INFO : EPOCH 7 - PROGRESS: at 85.39% examples, 141669 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:53,756 : INFO : EPOCH 7 - PROGRESS: at 86.11% examples, 138964 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:54,819 : INFO : EPOCH 7 - PROGRESS: at 86.83% examples, 136484 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:55,827 : INFO : EPOCH 7 - PROGRESS: at 87.47% examples, 134149 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:56,844 : INFO : EPOCH 7 - PROGRESS: at 88.03% examples, 131616 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:58,077 : INFO : EPOCH 7 - PROGRESS: at 88.75% examples, 128934 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:13:59,134 : INFO : EPOCH 7 - PROGRESS: at 89.39% examples, 126889 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:00,140 : INFO : EPOCH 7 - PROGRESS: at 90.03% examples, 125164 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:01,150 : INFO : EPOCH 7 - PROGRESS: at 90.67% examples, 123533 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:02,155 : INFO : EPOCH 7 - PROGRESS: at 91.31% examples, 122016 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:14:03,185 : INFO : EPOCH 7 - PROGRESS: at 91.95% examples, 120499 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:04,187 : INFO : EPOCH 7 - PROGRESS: at 92.59% examples, 119157 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:05,206 : INFO : EPOCH 7 - PROGRESS: at 93.23% examples, 117843 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:06,250 : INFO : EPOCH 7 - PROGRESS: at 93.78% examples, 116288 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:07,269 : INFO : EPOCH 7 - PROGRESS: at 94.51% examples, 115346 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:08,303 : INFO : EPOCH 7 - PROGRESS: at 95.23% examples, 114397 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:09,341 : INFO : EPOCH 7 - PROGRESS: at 95.87% examples, 113273 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:10,726 : INFO : EPOCH 7 - PROGRESS: at 96.66% examples, 111709 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:11,800 : INFO : EPOCH 7 - PROGRESS: at 97.38% examples, 110820 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:12,961 : INFO : EPOCH 7 - PROGRESS: at 98.09% examples, 109765 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:13,976 : INFO : EPOCH 7 - PROGRESS: at 98.73% examples, 108911 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:15,261 : INFO : EPOCH 7 - PROGRESS: at 99.45% examples, 107671 words/s, in_qsize 7, out_qsize 1
# 2026-03-13 18:14:15,701 : INFO : EPOCH 7: training on 5762447 raw words (5194720 effective words) took 48.1s, 107976 effective words/s
# 2026-03-13 18:14:16,747 : INFO : EPOCH 8 - PROGRESS: at 6.26% examples, 200530 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:17,753 : INFO : EPOCH 8 - PROGRESS: at 12.08% examples, 200553 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:18,764 : INFO : EPOCH 8 - PROGRESS: at 16.60% examples, 185801 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:19,783 : INFO : EPOCH 8 - PROGRESS: at 22.65% examples, 190702 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:14:20,837 : INFO : EPOCH 8 - PROGRESS: at 28.77% examples, 192263 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:21,842 : INFO : EPOCH 8 - PROGRESS: at 35.18% examples, 196875 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:14:22,867 : INFO : EPOCH 8 - PROGRESS: at 41.97% examples, 201968 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:23,904 : INFO : EPOCH 8 - PROGRESS: at 48.03% examples, 203043 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:24,979 : INFO : EPOCH 8 - PROGRESS: at 54.34% examples, 203817 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:26,019 : INFO : EPOCH 8 - PROGRESS: at 60.41% examples, 204858 words/s, in_qsize 1, out_qsize 0
# 2026-03-13 18:14:27,082 : INFO : EPOCH 8 - PROGRESS: at 66.74% examples, 204623 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:28,221 : INFO : EPOCH 8 - PROGRESS: at 70.14% examples, 198450 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:29,227 : INFO : EPOCH 8 - PROGRESS: at 74.19% examples, 197196 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:30,356 : INFO : EPOCH 8 - PROGRESS: at 77.88% examples, 193305 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:31,524 : INFO : EPOCH 8 - PROGRESS: at 79.65% examples, 184586 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:32,557 : INFO : EPOCH 8 - PROGRESS: at 80.32% examples, 177551 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:33,570 : INFO : EPOCH 8 - PROGRESS: at 80.97% examples, 171525 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:34,603 : INFO : EPOCH 8 - PROGRESS: at 81.63% examples, 165945 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:35,631 : INFO : EPOCH 8 - PROGRESS: at 82.28% examples, 160982 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:36,690 : INFO : EPOCH 8 - PROGRESS: at 82.92% examples, 156263 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:37,697 : INFO : EPOCH 8 - PROGRESS: at 83.56% examples, 152351 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:38,732 : INFO : EPOCH 8 - PROGRESS: at 84.27% examples, 148988 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:39,876 : INFO : EPOCH 8 - PROGRESS: at 84.99% examples, 145261 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:40,897 : INFO : EPOCH 8 - PROGRESS: at 85.64% examples, 142220 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:41,922 : INFO : EPOCH 8 - PROGRESS: at 86.27% examples, 139378 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:42,941 : INFO : EPOCH 8 - PROGRESS: at 86.91% examples, 136788 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:43,945 : INFO : EPOCH 8 - PROGRESS: at 87.55% examples, 134458 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:44,978 : INFO : EPOCH 8 - PROGRESS: at 88.19% examples, 132155 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:45,983 : INFO : EPOCH 8 - PROGRESS: at 88.83% examples, 130137 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:47,026 : INFO : EPOCH 8 - PROGRESS: at 89.47% examples, 128087 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:48,051 : INFO : EPOCH 8 - PROGRESS: at 90.11% examples, 126243 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:49,100 : INFO : EPOCH 8 - PROGRESS: at 90.75% examples, 124424 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:50,124 : INFO : EPOCH 8 - PROGRESS: at 91.39% examples, 122803 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:51,145 : INFO : EPOCH 8 - PROGRESS: at 92.03% examples, 121290 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:14:52,182 : INFO : EPOCH 8 - PROGRESS: at 92.67% examples, 119807 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:53,208 : INFO : EPOCH 8 - PROGRESS: at 93.30% examples, 118446 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:54,256 : INFO : EPOCH 8 - PROGRESS: at 93.94% examples, 117090 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:55,269 : INFO : EPOCH 8 - PROGRESS: at 94.59% examples, 115916 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:56,288 : INFO : EPOCH 8 - PROGRESS: at 95.24% examples, 114776 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:57,321 : INFO : EPOCH 8 - PROGRESS: at 95.87% examples, 113650 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:58,340 : INFO : EPOCH 8 - PROGRESS: at 96.50% examples, 112614 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:14:59,355 : INFO : EPOCH 8 - PROGRESS: at 97.14% examples, 111636 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:00,361 : INFO : EPOCH 8 - PROGRESS: at 97.77% examples, 110731 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:01,387 : INFO : EPOCH 8 - PROGRESS: at 98.41% examples, 109815 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:02,410 : INFO : EPOCH 8 - PROGRESS: at 99.05% examples, 108948 words/s, in_qsize 12, out_qsize 0
# 2026-03-13 18:15:03,411 : INFO : EPOCH 8 - PROGRESS: at 99.93% examples, 108730 words/s, in_qsize 1, out_qsize 1
# 2026-03-13 18:15:03,412 : INFO : EPOCH 8: training on 5762447 raw words (5195186 effective words) took 47.7s, 108902 effective words/s
# 2026-03-13 18:15:04,419 : INFO : EPOCH 9 - PROGRESS: at 4.46% examples, 147453 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:05,466 : INFO : EPOCH 9 - PROGRESS: at 10.58% examples, 174874 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:06,565 : INFO : EPOCH 9 - PROGRESS: at 16.60% examples, 180629 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:15:07,608 : INFO : EPOCH 9 - PROGRESS: at 22.65% examples, 185545 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:08,712 : INFO : EPOCH 9 - PROGRESS: at 28.77% examples, 186308 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:09,771 : INFO : EPOCH 9 - PROGRESS: at 35.18% examples, 190113 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:10,828 : INFO : EPOCH 9 - PROGRESS: at 41.70% examples, 193892 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:11,926 : INFO : EPOCH 9 - PROGRESS: at 48.03% examples, 195629 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:13,048 : INFO : EPOCH 9 - PROGRESS: at 54.34% examples, 196233 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:14,055 : INFO : EPOCH 9 - PROGRESS: at 60.16% examples, 197745 words/s, in_qsize 0, out_qsize 0
# 2026-03-13 18:15:15,093 : INFO : EPOCH 9 - PROGRESS: at 65.55% examples, 194814 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:16,153 : INFO : EPOCH 9 - PROGRESS: at 68.83% examples, 190289 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:17,171 : INFO : EPOCH 9 - PROGRESS: at 72.46% examples, 188173 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:18,176 : INFO : EPOCH 9 - PROGRESS: at 76.14% examples, 186542 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:15:19,316 : INFO : EPOCH 9 - PROGRESS: at 79.41% examples, 182511 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:20,399 : INFO : EPOCH 9 - PROGRESS: at 80.15% examples, 175113 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:21,457 : INFO : EPOCH 9 - PROGRESS: at 80.81% examples, 168840 words/s, in_qsize 16, out_qsize 0
# 2026-03-13 18:15:22,551 : INFO : EPOCH 9 - PROGRESS: at 81.47% examples, 162946 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:23,629 : INFO : EPOCH 9 - PROGRESS: at 82.12% examples, 157800 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:24,688 : INFO : EPOCH 9 - PROGRESS: at 82.76% examples, 153302 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:25,758 : INFO : EPOCH 9 - PROGRESS: at 83.40% examples, 149162 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:26,816 : INFO : EPOCH 9 - PROGRESS: at 84.04% examples, 145473 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:27,858 : INFO : EPOCH 9 - PROGRESS: at 84.67% examples, 142194 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:28,885 : INFO : EPOCH 9 - PROGRESS: at 85.31% examples, 139273 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:29,898 : INFO : EPOCH 9 - PROGRESS: at 85.95% examples, 136643 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:30,963 : INFO : EPOCH 9 - PROGRESS: at 86.59% examples, 133949 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:32,014 : INFO : EPOCH 9 - PROGRESS: at 87.23% examples, 131528 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:33,076 : INFO : EPOCH 9 - PROGRESS: at 87.87% examples, 129226 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:34,111 : INFO : EPOCH 9 - PROGRESS: at 88.51% examples, 127199 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:35,189 : INFO : EPOCH 9 - PROGRESS: at 89.15% examples, 125136 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:36,233 : INFO : EPOCH 9 - PROGRESS: at 89.79% examples, 123337 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:37,283 : INFO : EPOCH 9 - PROGRESS: at 90.43% examples, 121627 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:38,311 : INFO : EPOCH 9 - PROGRESS: at 91.07% examples, 120100 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:39,395 : INFO : EPOCH 9 - PROGRESS: at 91.71% examples, 118470 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:40,422 : INFO : EPOCH 9 - PROGRESS: at 92.35% examples, 117116 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:41,481 : INFO : EPOCH 9 - PROGRESS: at 92.99% examples, 115741 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:42,526 : INFO : EPOCH 9 - PROGRESS: at 93.63% examples, 114490 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:43,590 : INFO : EPOCH 9 - PROGRESS: at 94.27% examples, 113244 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:44,635 : INFO : EPOCH 9 - PROGRESS: at 94.91% examples, 112120 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:45,710 : INFO : EPOCH 9 - PROGRESS: at 95.55% examples, 110964 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:46,758 : INFO : EPOCH 9 - PROGRESS: at 96.19% examples, 109939 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:47,802 : INFO : EPOCH 9 - PROGRESS: at 96.82% examples, 108968 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:48,836 : INFO : EPOCH 9 - PROGRESS: at 97.46% examples, 108063 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:49,894 : INFO : EPOCH 9 - PROGRESS: at 98.09% examples, 107151 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:50,938 : INFO : EPOCH 9 - PROGRESS: at 98.73% examples, 106307 words/s, in_qsize 15, out_qsize 0
# 2026-03-13 18:15:51,979 : INFO : EPOCH 9 - PROGRESS: at 99.37% examples, 105511 words/s, in_qsize 8, out_qsize 0
# 2026-03-13 18:15:52,767 : INFO : EPOCH 9: training on 5762447 raw words (5194809 effective words) took 49.4s, 105264 effective words/s
# 2026-03-13 18:15:52,768 : INFO : Word2Vec lifecycle event {'msg': 'training on 57624470 raw words (51946874 effective words) took 470.3s, 110451 effective words/s', 'datetime': '2026-03-13T18:15:52.768381', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'train'}
# 2026-03-13 18:15:52,768 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=10037, vector_size=512, alpha=0.025>', 'datetime': '2026-03-13T18:15:52.768838', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'created'}
# 2026-03-13 18:15:52,769 : INFO : Word2Vec lifecycle event {'fname_or_handle': '..\\..\\data\\general-item2vec_mtg.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2026-03-13T18:15:52.769359', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'saving'}
# 2026-03-13 18:15:52,770 : INFO : not storing attribute cum_table
# 2026-03-13 18:15:52,800 : INFO : saved ..\..\data\general-item2vec_mtg.model
# Training complete! Saving model to ..\..\data\general-item2vec_mtg.model

# %% [markdown]
# Sanity Check embeddings:

# %%
model = Word2Vec.load(str(MODEL_OUTPUT))

for test_card in ["Ponder", "Demonic Tutor", "Lightning Bolt", "Swords to Plowshares", "Llanowar Elves", "Sol Ring"]:
    print("\n--- MODEL SANITY CHECK ---")

    try:
        similar_cards = model.wv.most_similar(test_card, topn=5)
        print(f"Cards most similar to '{test_card}':")
        for card, score in similar_cards:
            print(f"  - {card} (Confidence: {score:.2f})")
    except KeyError:
        print(f"'{test_card}' not found in vocabulary. Did you use the right casing?")
# Out:
# 2026-03-13 18:15:52,812 : INFO : loading Word2Vec object from ..\..\data\general-item2vec_mtg.model
# 2026-03-13 18:15:52,837 : INFO : loading wv recursively from ..\..\data\general-item2vec_mtg.model.wv.* with mmap=None
# 2026-03-13 18:15:52,838 : INFO : setting ignored attribute cum_table to None
# 2026-03-13 18:15:52,880 : INFO : Word2Vec lifecycle event {'fname': '..\\..\\data\\general-item2vec_mtg.model', 'datetime': '2026-03-13T18:15:52.880411', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'loaded'}
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Ponder':
#   - Preordain (Confidence: 0.58)
#   - Brainstorm (Confidence: 0.54)
#   - Merchant Scroll (Confidence: 0.51)
#   - Opt (Confidence: 0.44)
#   - Solve the Equation (Confidence: 0.43)
#
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Demonic Tutor':
#   - Vampiric Tutor (Confidence: 0.67)
#   - Imperial Seal (Confidence: 0.63)
#   - Dark Ritual (Confidence: 0.58)
#   - Tainted Pact (Confidence: 0.57)
#   - Orcish Bowmasters (Confidence: 0.56)
#
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Lightning Bolt':
#   - Pyroblast (Confidence: 0.61)
#   - Abrade (Confidence: 0.59)
#   - Jeska's Will (Confidence: 0.56)
#   - Pinnacle Monk (Confidence: 0.54)
#   - Dualcaster Mage (Confidence: 0.54)
#
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Swords to Plowshares':
#   - Path to Exile (Confidence: 0.63)
#   - Enlightened Tutor (Confidence: 0.59)
#   - Silence (Confidence: 0.56)
#   - Smothering Tithe (Confidence: 0.55)
#   - Drannith Magistrate (Confidence: 0.54)
#
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Llanowar Elves':
#   - Elvish Mystic (Confidence: 0.83)
#   - Fyndhorn Elves (Confidence: 0.83)
#   - Manglehorn (Confidence: 0.62)
#   - Endurance (Confidence: 0.57)
#   - Priest of Titania (Confidence: 0.55)
#
# --- MODEL SANITY CHECK ---
# Cards most similar to 'Sol Ring':
#   - Arcane Signet (Confidence: 0.57)
#   - Mana Vault (Confidence: 0.56)
#   - Gemstone Caverns (Confidence: 0.55)
#   - Lotus Petal (Confidence: 0.55)
#   - Command Tower (Confidence: 0.53)

# %% [markdown]
# ### 2: Preparing the Dataset

# %% [markdown]
# Gensim model needs to be PyTorch compatibile, using \<PAD\> and \<UNK\> tokens

# %%
def load_gensim_embeddings(gensim_model_path):
    """
    Extracts weights from Gensim and formats them for PyTorch.
    Adds <PAD> (ID 0) and <UNK> (ID 1).
    """
    print(f"Loading Gensim model from {gensim_model_path}...")
    g_model = Word2Vec.load(str(gensim_model_path))
    
    gensim_words = g_model.wv.index_to_key 
    vector_size = g_model.vector_size
    vocab_size = len(gensim_words) + 2
    
    embedding_matrix = np.zeros((vocab_size, vector_size))
    vocab = {"<PAD>": 0, "<UNK>": 1}
    
    for i, word in enumerate(gensim_words):
        pytorch_id = i + 2 
        vocab[word] = pytorch_id
        embedding_matrix[pytorch_id] = g_model.wv[word]
        
    embedding_tensor = torch.FloatTensor(embedding_matrix)
    print(f"Successfully loaded {vocab_size} vectors of dimension {vector_size}.")
    return vocab, embedding_tensor

# %% [markdown]
# This class parses the labelled EDH decks. It extracts the Moxfield power bracket, converts card names to their pre-trained integer IDs, and pads or truncates all decks to a fixed length of 115 so they can be processed in parallel batches.

# %%
class MTGDeckDataset(Dataset):
    def __init__(self, jsonl_filepath, vocab, max_len=115):
        
        torch.manual_seed(42)
        self.max_len = max_len
        self.vocab = vocab
        self.inputs = []
        self.labels = []
        
        print(f"Parsing decks from {jsonl_filepath}...")
        with open(jsonl_filepath, 'r', encoding='utf-8') as f:
            for line in f:
                if not line.strip(): continue
                data = json.loads(line)
                
                # --- 1. Robust Label Assignment ---
                source_str = data.get("source", "").lower()
                label = None
                # This matches "moxfield-edh-bracket-1", "bracket1", etc.
                for i in range(1, 6):
                    if f"bracket-{i}" in source_str or f"bracket{i}" in source_str:
                        label = i - 1
                        break
                
                if label is None: continue 
                
                # --- 2. Extract Cards (Keys from the dictionary) ---
                main = list(data.get("mainboard", {}).keys())
                side = list(data.get("sideboard", {}).keys())
                deck_strings = [c for c in (main + side) if c not in BASIC_LANDS]
                
                if len(deck_strings) < 10: continue
                
                # --- 3. Convert to IDs and Pad ---
                deck_ids = [self.vocab.get(card, 1) for card in deck_strings]
                if len(deck_ids) > self.max_len:
                    deck_ids = deck_ids[:self.max_len]
                else:
                    deck_ids += [0] * (self.max_len - len(deck_ids)) 
                    
                self.inputs.append(deck_ids)
                self.labels.append(label)

        self.inputs = torch.tensor(self.inputs, dtype=torch.long)
        self.labels = torch.tensor(self.labels, dtype=torch.long)
        print(f"Dataset ready: {len(self.inputs)} valid labeled decks found.")

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.labels[idx]

# %% [markdown]
# ### 3: Model Architecture

# %% [markdown]
# MTG decklists are permutation invariant -- "1 Thassa's Oracle, 1 Demonic Consultation" == "1 Demonic Consultation, 1 Thassa's Oracle".
# An attention layer would also be helpful: "1 Black Lotus" in a deck signals a high degree of power

# %% [markdown]
# This model is permutation-invariant. It processes each card independently (the Card Encoder), calculates a learned importance score for each card (the Attention Head), aggregates them via a weighted sum, and classifies the resulting deck vector (the Classifier).

# %%
class EDHAttentionDeepSets(nn.Module):
    def __init__(self, vocab_size, embedding_dim=EMBEDDING_SIZE, hidden_dim=128, pretrained_weights=None):
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        if pretrained_weights is not None:
            self.embedding.weight.data.copy_(pretrained_weights)
            self.embedding.weight.requires_grad = True
            
        self.card_mlp = nn.Sequential(
            nn.Linear(embedding_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )

        self.attention_net = nn.Sequential(
            nn.Linear(hidden_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        )
        
        self.deck_mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, 5) 
        )
        
    def forward(self, x):
        mask = (x != 0).float().unsqueeze(-1) 
        embedded = self.embedding(x)
        card_features = self.card_mlp(embedded) 
        
        attn_scores = self.attention_net(card_features) 
        attn_scores = attn_scores.masked_fill(mask == 0, -1e9)
        attn_weights = F.softmax(attn_scores, dim=1) 
        
        # Weighted MEAN (Better than Sum for preventing value explosion)
        deck_vector = torch.sum(attn_weights * card_features, dim=1)
        return self.deck_mlp(deck_vector)

# %% [markdown]
# ### 4: Training

# %% [markdown]
# With embeddings, prepared data, and classifier architecture, we can now train models and try to solve the problem.

# %%
# --- Settings ---
BATCH_SIZE = 64
EPOCHS = 15
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load the Word2Vec weights (still using MODEL_OUTPUT from the general corpus)
vocab_dict, pretrained_weights = load_gensim_embeddings(MODEL_OUTPUT)

# Load the Labeled EDH Dataset for classification
full_dataset = MTGDeckDataset(INPUT_EDH, vocab_dict)

# Splitting 80/10/10
train_size = int(0.8 * len(full_dataset))
val_size = int(0.1 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_ds, val_ds, test_ds = random_split(full_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# 2026-03-13 18:15:52,961 : INFO : loading Word2Vec object from ..\..\data\general-item2vec_mtg.model
# 2026-03-13 18:15:52,977 : INFO : loading wv recursively from ..\..\data\general-item2vec_mtg.model.wv.* with mmap=None
# Loading Gensim model from ..\..\data\general-item2vec_mtg.model...
# 2026-03-13 18:15:52,978 : INFO : setting ignored attribute cum_table to None
# 2026-03-13 18:15:53,022 : INFO : Word2Vec lifecycle event {'fname': '..\\..\\data\\general-item2vec_mtg.model', 'datetime': '2026-03-13T18:15:53.022315', 'gensim': '4.4.0', 'python': '3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26200-SP0', 'event': 'loaded'}
# Successfully loaded 10039 vectors of dimension 512.
# Parsing decks from ..\..\data\edh-decks.jsonl...
# Dataset ready: 44496 valid labeled decks found.

# %% [markdown]
# We apply a much lower learning rate to the pretrained embedding weights (1e-5) to avoid catastrophic forgetting of the general MTG knowledge, while allowing the new classifier layers to learn at a standard pace (3e-4).

# %%
# Setup Model
model = EDHAttentionDeepSets(
    vocab_size=len(vocab_dict), 
    embedding_dim=EMBEDDING_SIZE, 
    hidden_dim=128,               
    pretrained_weights=pretrained_weights
).to(DEVICE)

criterion = nn.CrossEntropyLoss()

# Differential Learning Rates - give pre-trained embeddings lower learning rate as to not disturb the good logic built previously, but tune for the EDH space. Classifier parameters have a quicker learning rate as they haven't "seen" as many decklists
optimizer = optim.AdamW([
    {'params': model.embedding.parameters(), 'lr': 1e-5}, 
    {'params': [p for n, p in model.named_parameters() if "embedding" not in n], 'lr': 3e-4}
], weight_decay=1e-4)

# %%
def train_net(net, train_loader, val_loader, learning_rate=0.0003, num_epochs=15):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net.to(device)
    
    criterion = nn.CrossEntropyLoss()
    
    # Differential Learning Rates
    optimizer = optim.AdamW([
        {'params': net.embedding.parameters(), 'lr': 1e-5}, # Low LR for Word2Vec, already seen lots of decks
        {'params': [p for n, p in net.named_parameters() if "embedding" not in n], 
         'lr': learning_rate} # Normal LR for the classifier
    ], weight_decay=1e-4)

    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    
    # Reduces the learning rate by half if the validation loss doesn't improve for 3 epochs
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    for epoch in range(num_epochs):
        net.train()
        total_loss, correct, total = 0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)

        val_acc, val_loss = evaluate(net, val_loader, criterion)
        
        scheduler.step(val_loss)
        
        history['train_loss'].append(total_loss / len(train_loader))
        history['train_acc'].append(100 * correct / total)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(100 * val_acc)

        print(f"Epoch {epoch+1}: Train Acc: {history['train_acc'][-1]:.2f}% | Val Acc: {history['val_acc'][-1]:.2f}%")

    return history

def evaluate(net, loader, criterion):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)
    return correct / total, total_loss / len(loader)

# %%
def plot_training_curve(history):
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.title("Loss")
    plt.plot(history['train_loss'], label="Train")
    plt.plot(history['val_loss'], label="Validation")
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.title("Accuracy")
    plt.plot(history['train_acc'], label="Train")
    plt.plot(history['val_acc'], label="Validation")
    plt.legend()
    plt.show()

# %% [markdown]
# Check for overfitting capacity. Before running a full training sweep, we test if the model can perfectly memorize a tiny subset of 20 decks. Hitting 100% accuracy here proves that the architecture has enough capacity and the gradients are flowing correctly.

# %%
# 1. Grab 20 indices from the train_dataset (the warehouse, not the loader)
small_indices = range(20)
small_ds = torch.utils.data.Subset(train_ds, small_indices)

# 2. Create the loader for these 20 decks
small_loader = DataLoader(small_ds, batch_size=20)

# 3. Initialize the model with named arguments
overfit_model = EDHAttentionDeepSets(
    vocab_size=len(vocab_dict), 
    embedding_dim=EMBEDDING_SIZE, 
    hidden_dim=128, 
    pretrained_weights=pretrained_weights
).to(DEVICE)

# 4. Remove dropout for overfitting test (makes it easier to hit 100%)
overfit_model.deck_mlp[3] = nn.Identity() 

# 5. Train
history = train_net(overfit_model, small_loader, small_loader, learning_rate=0.001, num_epochs=100)
plot_training_curve(history)
# Out:
# Epoch 1: Train Acc: 25.00% | Val Acc: 15.00%
# Epoch 2: Train Acc: 90.00% | Val Acc: 15.00%
# Epoch 3: Train Acc: 100.00% | Val Acc: 20.00%
# Epoch 4: Train Acc: 100.00% | Val Acc: 45.00%
# Epoch 5: Train Acc: 100.00% | Val Acc: 65.00%
# Epoch 6: Train Acc: 100.00% | Val Acc: 75.00%
# Epoch 7: Train Acc: 100.00% | Val Acc: 95.00%
# Epoch 8: Train Acc: 100.00% | Val Acc: 95.00%
# Epoch 9: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 10: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 12: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 15: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 16: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 17: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 18: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 19: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 20: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 21: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 22: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 23: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 24: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 25: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 26: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 27: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 28: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 29: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 30: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 31: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 32: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 33: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 34: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 35: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 36: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 37: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 38: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 39: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 40: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 41: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 42: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 43: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 44: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 45: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 46: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 47: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 48: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 49: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 50: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 51: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 52: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 53: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 54: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 55: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 56: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 57: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 58: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 59: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 60: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 61: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 62: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 63: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 64: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 65: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 66: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 67: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 68: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 69: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 70: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 71: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 72: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 73: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 74: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 75: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 76: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 77: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 78: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 79: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 80: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 81: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 82: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 83: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 84: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 85: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 86: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 87: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 88: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 89: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 90: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 91: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 92: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 93: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 94: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 95: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 96: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 97: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 98: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 99: Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 100: Train Acc: 100.00% | Val Acc: 100.00%

# %% [markdown]
# ### 4. Hyperparameter Search

# %% [markdown]
# We test different learning rates an different hidden layer sizes to find the optimal balance between model capacity and generalization.

# %%
results = {}
for lr in [0.003, 0.001, 0.0003]:
    for hidden in [64, 128, 256]:
        print(f"\n--- Testing LR: {lr}, Hidden: {hidden} ---")
        # Now passing 'hidden' into the model
        m = EDHAttentionDeepSets(len(vocab_dict), embedding_dim=EMBEDDING_SIZE, hidden_dim=hidden, pretrained_weights=pretrained_weights)
        
        # We only run for 10 epochs to save time during the search
        h = train_net(m, train_loader, val_loader, learning_rate=lr, num_epochs=10)
        
        results[f"lr{lr}_h{hidden}"] = h
        plot_training_curve(h)
# Out:
# --- Testing LR: 0.003, Hidden: 64 ---
# Epoch 1: Train Acc: 20.31% | Val Acc: 20.52%
# Epoch 2: Train Acc: 20.31% | Val Acc: 20.09%
# Epoch 3: Train Acc: 20.63% | Val Acc: 20.63%
# Epoch 4: Train Acc: 20.96% | Val Acc: 20.52%
# Epoch 5: Train Acc: 20.93% | Val Acc: 20.90%
# Epoch 6: Train Acc: 21.03% | Val Acc: 20.90%
# Epoch 7: Train Acc: 21.16% | Val Acc: 20.88%
# Epoch 8: Train Acc: 20.99% | Val Acc: 20.90%
# Epoch 9: Train Acc: 21.10% | Val Acc: 20.79%
# Epoch 10: Train Acc: 20.92% | Val Acc: 20.90%
# --- Testing LR: 0.003, Hidden: 128 ---
# Epoch 1: Train Acc: 20.06% | Val Acc: 20.84%
# Epoch 2: Train Acc: 20.56% | Val Acc: 20.84%
# Epoch 3: Train Acc: 20.76% | Val Acc: 20.77%
# Epoch 4: Train Acc: 20.86% | Val Acc: 20.93%
# Epoch 5: Train Acc: 21.10% | Val Acc: 20.84%
# Epoch 6: Train Acc: 20.95% | Val Acc: 20.77%
# Epoch 7: Train Acc: 21.00% | Val Acc: 20.93%
# Epoch 8: Train Acc: 21.00% | Val Acc: 20.93%
# Epoch 9: Train Acc: 21.04% | Val Acc: 20.93%
# Epoch 10: Train Acc: 21.04% | Val Acc: 20.84%
# --- Testing LR: 0.003, Hidden: 256 ---
# Epoch 1: Train Acc: 20.26% | Val Acc: 19.94%
# Epoch 2: Train Acc: 20.40% | Val Acc: 18.86%
# Epoch 3: Train Acc: 20.65% | Val Acc: 20.84%
# Epoch 4: Train Acc: 20.84% | Val Acc: 20.84%
# Epoch 5: Train Acc: 21.02% | Val Acc: 20.84%
# Epoch 6: Train Acc: 20.89% | Val Acc: 20.77%
# Epoch 7: Train Acc: 21.02% | Val Acc: 20.90%
# Epoch 8: Train Acc: 20.99% | Val Acc: 20.90%
# Epoch 9: Train Acc: 20.98% | Val Acc: 20.90%
# Epoch 10: Train Acc: 21.03% | Val Acc: 20.90%
# --- Testing LR: 0.001, Hidden: 64 ---
# Epoch 1: Train Acc: 20.20% | Val Acc: 20.63%
# Epoch 2: Train Acc: 20.38% | Val Acc: 20.34%
# Epoch 3: Train Acc: 20.65% | Val Acc: 20.70%
# Epoch 4: Train Acc: 20.28% | Val Acc: 20.16%
# Epoch 5: Train Acc: 20.47% | Val Acc: 19.17%
# Epoch 6: Train Acc: 20.67% | Val Acc: 20.23%
# Epoch 7: Train Acc: 20.99% | Val Acc: 20.45%
# Epoch 8: Train Acc: 20.88% | Val Acc: 20.68%
# Epoch 9: Train Acc: 21.17% | Val Acc: 20.61%
# Epoch 10: Train Acc: 21.56% | Val Acc: 18.99%
# --- Testing LR: 0.001, Hidden: 128 ---
# Epoch 1: Train Acc: 19.63% | Val Acc: 20.18%
# Epoch 2: Train Acc: 19.85% | Val Acc: 20.68%
# Epoch 3: Train Acc: 20.07% | Val Acc: 20.07%
# Epoch 4: Train Acc: 20.43% | Val Acc: 20.52%
# Epoch 5: Train Acc: 20.52% | Val Acc: 19.40%
# Epoch 6: Train Acc: 20.54% | Val Acc: 20.07%
# Epoch 7: Train Acc: 20.20% | Val Acc: 20.93%
# Epoch 8: Train Acc: 20.86% | Val Acc: 20.23%
# Epoch 9: Train Acc: 20.35% | Val Acc: 20.79%
# Epoch 10: Train Acc: 20.45% | Val Acc: 20.45%
# --- Testing LR: 0.001, Hidden: 256 ---
# Epoch 1: Train Acc: 20.34% | Val Acc: 20.81%
# Epoch 2: Train Acc: 20.40% | Val Acc: 19.64%
# Epoch 3: Train Acc: 20.62% | Val Acc: 20.84%
# Epoch 4: Train Acc: 20.90% | Val Acc: 20.84%
# Epoch 5: Train Acc: 20.83% | Val Acc: 20.90%
# Epoch 6: Train Acc: 20.85% | Val Acc: 20.90%
# Epoch 7: Train Acc: 20.87% | Val Acc: 20.90%
# Epoch 8: Train Acc: 20.90% | Val Acc: 20.77%
# Epoch 9: Train Acc: 20.85% | Val Acc: 20.93%
# Epoch 10: Train Acc: 20.95% | Val Acc: 20.90%
# --- Testing LR: 0.0003, Hidden: 64 ---
# Epoch 1: Train Acc: 19.91% | Val Acc: 20.25%
# Epoch 2: Train Acc: 20.08% | Val Acc: 19.13%
# Epoch 3: Train Acc: 20.45% | Val Acc: 19.02%
# Epoch 4: Train Acc: 20.34% | Val Acc: 19.76%
# Epoch 5: Train Acc: 20.26% | Val Acc: 19.55%
# Epoch 6: Train Acc: 20.55% | Val Acc: 20.16%
# Epoch 7: Train Acc: 20.20% | Val Acc: 19.58%
# Epoch 8: Train Acc: 20.54% | Val Acc: 19.08%
# Epoch 9: Train Acc: 21.01% | Val Acc: 20.14%
# Epoch 10: Train Acc: 20.79% | Val Acc: 19.38%
# --- Testing LR: 0.0003, Hidden: 128 ---
# Epoch 1: Train Acc: 19.89% | Val Acc: 20.52%
# Epoch 2: Train Acc: 19.82% | Val Acc: 18.99%
# Epoch 3: Train Acc: 20.44% | Val Acc: 19.91%
# Epoch 4: Train Acc: 20.56% | Val Acc: 20.86%
# Epoch 5: Train Acc: 20.63% | Val Acc: 20.88%
# Epoch 6: Train Acc: 20.78% | Val Acc: 20.81%
# Epoch 7: Train Acc: 20.71% | Val Acc: 20.81%
# Epoch 8: Train Acc: 20.88% | Val Acc: 20.84%
# Epoch 9: Train Acc: 20.94% | Val Acc: 18.75%
# Epoch 10: Train Acc: 20.85% | Val Acc: 20.86%
# --- Testing LR: 0.0003, Hidden: 256 ---
# Epoch 1: Train Acc: 19.74% | Val Acc: 20.88%
# Epoch 2: Train Acc: 19.98% | Val Acc: 18.97%
# Epoch 3: Train Acc: 20.75% | Val Acc: 19.24%
# Epoch 4: Train Acc: 20.29% | Val Acc: 19.20%
# Epoch 5: Train Acc: 20.35% | Val Acc: 20.93%
# Epoch 6: Train Acc: 20.87% | Val Acc: 19.94%
# Epoch 7: Train Acc: 20.26% | Val Acc: 19.64%
# Epoch 8: Train Acc: 20.37% | Val Acc: 19.47%
# Epoch 9: Train Acc: 21.41% | Val Acc: 19.89%
# Epoch 10: Train Acc: 21.76% | Val Acc: 19.76%

# %% [markdown]
# Some of these are promising. Training for more epochs:

# %%
results = {}
for lr,hidden in [(0.003, 64), (0.001,128), (0.0003, 256)]:
    print(f"\n--- Testing LR: {lr}, Hidden: {hidden} ---")
    # Now passing 'hidden' into the model
    m = EDHAttentionDeepSets(len(vocab_dict), embedding_dim=EMBEDDING_SIZE, hidden_dim=hidden, pretrained_weights=pretrained_weights)
    
    # We only run for 10 epochs to save time during the search
    h = train_net(m, train_loader, val_loader, learning_rate=lr, num_epochs=25)
    
    results[f"lr{lr}_h{hidden}"] = h
    plot_training_curve(h)
    
    torch.save(m.state_dict(), f'lr{lr}_h{hidden}_model_weights.pth')
# Out:
# --- Testing LR: 0.003, Hidden: 64 ---
# Epoch 1: Train Acc: 20.11% | Val Acc: 19.42%
# Epoch 2: Train Acc: 20.58% | Val Acc: 20.59%
# Epoch 3: Train Acc: 20.40% | Val Acc: 20.16%
# Epoch 4: Train Acc: 20.24% | Val Acc: 19.69%
# Epoch 5: Train Acc: 20.58% | Val Acc: 20.95%
# Epoch 6: Train Acc: 20.79% | Val Acc: 20.81%
# Epoch 7: Train Acc: 20.75% | Val Acc: 20.84%
# Epoch 8: Train Acc: 21.00% | Val Acc: 20.61%
# Epoch 9: Train Acc: 20.91% | Val Acc: 20.90%
# Epoch 10: Train Acc: 20.95% | Val Acc: 20.90%
# Epoch 11: Train Acc: 21.01% | Val Acc: 20.90%
# Epoch 12: Train Acc: 20.89% | Val Acc: 20.90%
# Epoch 13: Train Acc: 21.07% | Val Acc: 20.90%
# Epoch 14: Train Acc: 21.03% | Val Acc: 20.90%
# Epoch 15: Train Acc: 20.90% | Val Acc: 20.90%
# Epoch 16: Train Acc: 21.09% | Val Acc: 21.04%
# Epoch 17: Train Acc: 21.09% | Val Acc: 20.90%
# Epoch 18: Train Acc: 21.03% | Val Acc: 20.90%
# Epoch 19: Train Acc: 21.10% | Val Acc: 20.90%
# Epoch 20: Train Acc: 21.09% | Val Acc: 20.90%
# Epoch 21: Train Acc: 21.08% | Val Acc: 20.90%
# Epoch 22: Train Acc: 21.10% | Val Acc: 20.90%
# Epoch 23: Train Acc: 21.10% | Val Acc: 20.90%
# Epoch 24: Train Acc: 21.10% | Val Acc: 20.90%
# Epoch 25: Train Acc: 21.09% | Val Acc: 20.90%
# --- Testing LR: 0.001, Hidden: 128 ---
# Epoch 1: Train Acc: 19.88% | Val Acc: 19.98%
# Epoch 2: Train Acc: 20.26% | Val Acc: 20.48%
# Epoch 3: Train Acc: 20.32% | Val Acc: 20.32%
# Epoch 4: Train Acc: 20.18% | Val Acc: 20.93%
# Epoch 5: Train Acc: 20.41% | Val Acc: 20.88%
# Epoch 6: Train Acc: 20.56% | Val Acc: 21.20%
# Epoch 7: Train Acc: 20.70% | Val Acc: 20.88%
# Epoch 8: Train Acc: 21.12% | Val Acc: 20.66%
# Epoch 9: Train Acc: 21.08% | Val Acc: 20.79%
# Epoch 10: Train Acc: 20.98% | Val Acc: 20.90%
# Epoch 11: Train Acc: 20.98% | Val Acc: 20.63%
# Epoch 12: Train Acc: 21.01% | Val Acc: 20.88%
# Epoch 13: Train Acc: 21.07% | Val Acc: 20.12%
# Epoch 14: Train Acc: 21.33% | Val Acc: 20.43%
# Epoch 15: Train Acc: 21.72% | Val Acc: 20.50%
# Epoch 16: Train Acc: 22.00% | Val Acc: 20.57%
# Epoch 17: Train Acc: 22.20% | Val Acc: 20.36%
# Epoch 18: Train Acc: 22.59% | Val Acc: 20.14%
# Epoch 19: Train Acc: 23.05% | Val Acc: 20.05%
# Epoch 20: Train Acc: 23.04% | Val Acc: 19.69%
# Epoch 21: Train Acc: 23.32% | Val Acc: 19.11%
# Epoch 22: Train Acc: 23.69% | Val Acc: 19.55%
# Epoch 23: Train Acc: 23.65% | Val Acc: 19.60%
# Epoch 24: Train Acc: 23.74% | Val Acc: 19.58%
# Epoch 25: Train Acc: 23.89% | Val Acc: 19.38%
# --- Testing LR: 0.0003, Hidden: 256 ---
# Epoch 1: Train Acc: 19.66% | Val Acc: 19.76%
# Epoch 2: Train Acc: 20.36% | Val Acc: 18.95%
# Epoch 3: Train Acc: 20.53% | Val Acc: 20.63%
# Epoch 4: Train Acc: 20.38% | Val Acc: 20.86%
# Epoch 5: Train Acc: 20.61% | Val Acc: 19.94%
# Epoch 6: Train Acc: 20.86% | Val Acc: 20.79%
# Epoch 7: Train Acc: 20.61% | Val Acc: 20.84%
# Epoch 8: Train Acc: 20.90% | Val Acc: 18.70%
# Epoch 9: Train Acc: 20.69% | Val Acc: 20.99%
# Epoch 10: Train Acc: 20.70% | Val Acc: 20.79%
# Epoch 11: Train Acc: 20.87% | Val Acc: 18.81%
# Epoch 12: Train Acc: 20.76% | Val Acc: 20.79%
# Epoch 13: Train Acc: 20.90% | Val Acc: 20.81%
# Epoch 14: Train Acc: 20.82% | Val Acc: 20.70%
# Epoch 15: Train Acc: 20.83% | Val Acc: 20.84%
# Epoch 16: Train Acc: 20.94% | Val Acc: 20.90%
# Epoch 17: Train Acc: 20.82% | Val Acc: 20.72%
# Epoch 18: Train Acc: 20.91% | Val Acc: 20.93%
# Epoch 19: Train Acc: 21.05% | Val Acc: 20.97%
# Epoch 20: Train Acc: 20.84% | Val Acc: 20.72%
# Epoch 21: Train Acc: 20.78% | Val Acc: 20.59%
# Epoch 22: Train Acc: 21.16% | Val Acc: 20.75%
# Epoch 23: Train Acc: 20.90% | Val Acc: 20.79%
# Epoch 24: Train Acc: 21.01% | Val Acc: 20.72%
# Epoch 25: Train Acc: 20.87% | Val Acc: 20.72%

# %% [markdown]
# ### 5. Model Interpretation: Visualizing Attention

# %% [markdown]
# To understand why the model chose a specific Bracket, we can extract the attention weights.
# High attention weights indicate "power outliers" that the model used to justify the deck's score.

# %%
def visualize_deck_attention(net, deck_ids, vocab, top_n=10, real_label=None):
    net.eval()
    device = next(net.parameters()).device
    inv_vocab = {v: k for k, v in vocab.items()}
    
    with torch.no_grad():
        # 1. Ensure deck_ids is a tensor and add batch dim
        if not isinstance(deck_ids, torch.Tensor):
            deck_ids = torch.tensor(deck_ids)
        x = deck_ids.unsqueeze(0).to(device) 
        
        # 2. Get mask and weights
        mask = (x != 0).float().unsqueeze(-1)
        embedded = net.embedding(x)
        card_features = net.card_mlp(embedded)
        
        attn_scores = net.attention_net(card_features)
        attn_scores = attn_scores.masked_fill(mask == 0, -1e9) # Kill padding influence
        attn_weights = F.softmax(attn_scores, dim=1) 

        # Prediction logic
        deck_vector = torch.sum(attn_weights * card_features, dim=1)
        logits = net.deck_mlp(deck_vector)
        pred_label = torch.argmax(logits, dim=1).item() + 1

    # 3. CRITICAL FIX: Filter out padding (ID 0) AND unknown tokens (ID 1)
    weights_np = attn_weights.squeeze().cpu().numpy()
    ids_np = deck_ids.cpu().numpy()
    
    # Exclude both 0 and 1 from the valid indices
    valid_indices = (ids_np != 0) & (ids_np != 1)
    clean_ids = ids_np[valid_indices]
    clean_weights = weights_np[valid_indices]
    
    # Map back to names
    card_names = [inv_vocab.get(i, f"ID:{i}") for i in clean_ids]

    # 4. Sort and Slice
    sorted_indices = np.argsort(clean_weights)[::-1][:top_n]
    top_cards = [card_names[i] for i in sorted_indices]
    top_weights = [clean_weights[i] for i in sorted_indices]

    # 5. Plotting
    plt.figure(figsize=(10, 6))
    plt.barh(top_cards, top_weights, color='teal')
    plt.xlabel("Attention Weight (Importance)")
    
    label_text = f"Predicted: Bracket {pred_label}"
    if real_label is not None:
        label_text += f" (Actual: Bracket {real_label + 1})"
    
    plt.title(label_text)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

# %%
# Test on known decklist
# Specific decklist as a raw string
raw_deck_text = """1 Birgi, God of Storytelling
1 Dragon's Rage Channeler
1 Esper Sentinel
1 Faerie Mastermind
1 Grand Abolisher
1 Hexing Squelcher
1 Lotho, Corrupt Shirriff
1 Memnite
1 Mockingbird
1 Opposition Agent
1 Professional Face-Breaker
1 Ragavan, Nimble Pilferer
1 Ranger-Captain of Eos
1 Simian Spirit Guide
1 Tataru Taru
1 Thassa's Oracle
1 Valley Floodcaller
1 Voice of Victory
1 Arcane Signet
1 Chrome Mox
1 Lion's Eye Diamond
1 Lotus Petal
1 Mana Vault
1 Mox Amber
1 Mox Diamond
1 Mox Opal
1 Sol Ring
1 Talisman of Progress
1 Wishclaw Talisman
1 Ad Nauseam
1 An Offer You Can't Refuse
1 Borne Upon a Wind
1 Brain Freeze
1 Cabal Ritual
1 Chain of Vapor
1 Culling the Weak
1 Dark Ritual
1 Deflecting Swat
1 Demonic Consultation
1 Enlightened Tutor
1 Fierce Guardianship
1 Final Fortune
1 Flusterstorm
1 Force of Negation
1 Force of Will
1 Into the Flood Maw
1 Intuition
1 Mental Misstep
1 Mindbreak Trap
1 Mystical Tutor
1 Pact of Negation
1 Red Elemental Blast
1 Silence
1 Snapback
1 Swan Song
1 Tainted Pact
1 Vampiric Tutor
1 Beseech the Mirror
1 Demonic Tutor
1 Diabolic Intent
1 Gamble
1 Gitaxian Probe
1 Imperial Seal
1 Mnemonic Betrayal
1 Rite of Flame
1 Sevinne's Reclamation
1 Wheel of Fortune
1 Mystic Remora
1 Necropotence
1 Rhystic Study
1 Smothering Tithe
1 Underworld Breach
1 Ancient Tomb
1 Arid Mesa
1 Badlands
1 Bloodstained Mire
1 Cavern of Souls
1 City of Brass
1 City of Traitors
1 Command Tower
1 Exotic Orchard
1 Flooded Strand
1 Gemstone Caverns
1 Mana Confluence
1 Marsh Flats
1 Misty Rainforest
1 Otawara, Soaring City
1 Plateau
1 Polluted Delta
1 Scalding Tarn
1 Scrubland
1 Starting Town
1 Tundra
1 Underground Sea
1 Verdant Catacombs
1 Volcanic Island
1 Watery Grave
1 Windswept Heath
Sideboard
1 Kraum, Ludevic's Opus
1 Tymna the Weaver"""

# Processing the decklist
deck_cards = []
for line in raw_deck_text.strip().split('\n'):
    line = line.strip()
    if not line or line.lower() == 'sideboard': 
        continue
    
    # Regex to capture the number and extract just the card name
    match = re.match(r'^\d+\s+(.+)$', line)
    if match:
        card_name = match.group(1)
        if card_name not in BASIC_LANDS:
            deck_cards.append(card_name)

# Convert to Vocab IDs (using 1 for <UNK>)
max_len = 115
deck_ids = [vocab_dict.get(card, 1) for card in deck_cards]

#Pad or truncate to 115
if len(deck_ids) > max_len:
    deck_ids = deck_ids[:max_len]
else:
    deck_ids += [0] * (max_len - len(deck_ids)) 

# Convert to tensor and pass to your visualization function
custom_deck_tensor = torch.tensor(deck_ids, dtype=torch.long)

print(f"Parsed {len(deck_cards)} non-basic cards.")
# Pass None for real_label since this is a manual test without a ground truth label
visualize_deck_attention(m, custom_deck_tensor, vocab_dict, top_n=10, real_label=None)
# Out:
# Parsed 100 non-basic cards.

# %% [markdown]
# ### 6. Final Evaluation on Held-out Test Set

# %% [markdown]
# This represents the true performance of our best model on completely unseen data.

# %%
def final_test_report(net, test_loader, criterion):
    net.eval()
    test_acc, test_loss = evaluate(net, test_loader, criterion)
    print("="*30)
    print(f"FINAL TEST ACCURACY: {test_acc*100:.2f}%")
    print(f"FINAL TEST LOSS:     {test_loss:.4f}")
    print("="*30)

# %%
final_test_report(m,test_loader,criterion)
# Out:
# ==============================
# FINAL TEST ACCURACY: 20.42%
# FINAL TEST LOSS:     1.6139
# ==============================
